# %%
use Data::Reshapers;
use Data::TypeSystem;
use Data::Translators;

my $tbl = get-titanic-dataset.pick(3);
# Out:
# ({id => 820, passengerAge => -1, passengerClass => 3rd, passengerSex => female, passengerSurvival => survived} {id => 929, passengerAge => -1, passengerClass => 3rd, passengerSex => female, passengerSurvival => died} {id => 58, passengerAge => 40, passengerClass => 1st, passengerSex => female, passengerSurvival => survived})

# %%
deduce-type($tbl);
# Out:
# Vector(Assoc(Atom((Str)), Atom((Str)), 5), 3)

# %%
my $html = ($tbl ==> data-translation)
# Out:
# <table border="1"><thead><tr><th>passengerSurvival</th><th>passengerSex</th><th>passengerClass</th><th>id</th><th>passengerAge</th></tr></thead><tbody><tr><td>survived</td><td>female</td><td>3rd</td><td>1062</td><td>30</td></tr><tr><td>survived</td><td>female</td><td>2nd</td><td>534</td><td>20</td></tr><tr><td>died</td><td>male</td><td>1st</td><td>159</td><td>60</td></tr></tbody></table>

# %%
$html
# Out:
# <table border="1"><thead><tr><th>passengerSurvival</th><th>passengerSex</th><th>passengerClass</th><th>id</th><th>passengerAge</th></tr></thead><tbody><tr><td>survived</td><td>female</td><td>3rd</td><td>1062</td><td>30</td></tr><tr><td>survived</td><td>female</td><td>2nd</td><td>534</td><td>20</td></tr><tr><td>died</td><td>male</td><td>1st</td><td>159</td><td>60</td></tr></tbody></table>

# %%
# %%html
# $html
# Out:
# <table border="1"><thead><tr><th>passengerSurvival</th><th>passengerSex</th><th>passengerClass</th><th>id</th><th>passengerAge</th></tr></thead><tbody><tr><td>survived</td><td>female</td><td>3rd</td><td>1062</td><td>30</td></tr><tr><td>survived</td><td>female</td><td>2nd</td><td>534</td><td>20</td></tr><tr><td>died</td><td>male</td><td>1st</td><td>159</td><td>60</td></tr></tbody></table>

# %%
# Out:
# ()

# %%
# Out:
# ()
