# %%
#% openai
How many people live in EU?
# Out:
# As of 2021, the population of the European Union is approximately 447 million people.

# %%
my %authors = (
'zef:raku-community-modules' => 'Various Artistes',
'zef:l10n'        => 'Various Artistes',
'zef:FCO'         => 'Fernando Correa de Oliveira',
'zef:antononcube' => 'Anton Antonov',
'zef:finanalyst'  => 'Richard Hainsworth',
'zef:librasteve'  => 'Steve Roe',
'zef:avuserow'    => 'Adrian Kreher',
'zef:lizmat'      => 'Elizabeth Mattijsen',
'zef:jjatria'     => 'JJ Atria',
'zef:wayland'     => 'Tim Nelson',
'zef:grizzlysmit' => 'Francis Grizzly Smit',
'zef:melezhik'    => 'Alexey Melezhik',
'zef:dwarring'    => 'David Warring',
'zef:bduggan'     => 'Brian Duggan',
'zef:tony-o'      => 'Tony O\'Dell',
'zef:ingy'        => 'Ingy döt Net',
'github:nkh'      => 'Nadim Khemir',
'zef:nkh'         => 'Nadim Khemir',
'zef:patrickb'    => 'Patrick Böker',
'zef:arunvickram' => 'Arun Vickram',
'zef:kuerbis'     => 'Matthäus Kiem',
'zef:japhb'       => 'Geoffrey Broadwell',
'zef:ab5tract'    => 'John Longwalker',
'zef:arkuiat'     => 'Eric Forste',
);

# %authors.values;

# %%
use LLM::Functions;

my &fcp = llm-function({"Has $_ given any conference talks?"});

# %%
# %authors.values.map: {fcp $_}

# %% [markdown]
# # Coders Who Have Given Talks at Conferences
#
# ## ✅ Conference Speakers
#
# ### 1. Fernando Corrêa de Oliveira
# - **Nickname**: SmokeMachine
# - **Talks**:
# - 2023: "History and future of FET"
# - 2022: "Red, an ORM for Raku"
# - **Source**: [conf.raku.org](https://conf.raku.org/user/fernando-corradeoliveira?utm_source=chatgpt.com)
#
# ### 2. Richard Hainsworth
# - **Nickname**: finanalyst
# - **Talks**:
# - 2023: "RakuDoc and Raku Documentation"
# - **Source**: [conf.raku.org](https://conf.raku.org/user/richard-hainsworth?utm_source=chatgpt.com)
#
# ### 3. Elizabeth Mattijsen
# - **Talks**:
# - 2023: "Raku Steering Council Q&A"
# - 2022: "So you wanted to teach programming to your niece, but she doesn't know English"
# - 2021: "Sigils. Once you know them, you'll love them in the Raku Programming Language."
# - **Source**: [conf.raku.org](https://conf.raku.org/user/elizabeth-mattijsen?utm_source=chatgpt.com)
#
# ### 4. Anton Antonov
# - **Talks**:
# - 2023: "Integrating Large Language Models with Raku"
# - 2022: "Implementing Machine Learning algorithms in Raku"
# - 2021: "Raku for Prediction"
# - **Source**: [conf.raku.org](https://conf.raku.org/user/anton-antonov?utm_source=chatgpt.com)
#
# ### 5. JJ Atria
# - **Talks**:
# - 2023: "Just submitted a talk to the #rakulang conference coming up next month."
# - **Source**: [Twitter](https://twitter.com/jjatria/status/1552068303283183619?utm_source=chatgpt.com)
#
# ### 6. Steve Roe
# - **Talks**:
# - Discussed how Raku provides practical alternatives to Regexs and recursive descent modules.
# - **Source**: [4angle speakers](https://speakers.4angle.com/person/6773?utm_source=chatgpt.com)

# %% [markdown]
# Quick question - are you considering attending the Fosdem 2026 event. It will take place on Saturday 31st January and Sunday 1st February 2026 at the usual location, ULB Campus Solbosch in Brussels.I'm asking because I think you would be the best person to give a talk on xxx in the Raku devroom. If you are interested please let me have a working title and a very short summary (1 sentence). For now this is to help us show to the organisers the kind of content that we can share as part of our devroom submission. If that is successful then we can work on a more formal call for papers. (We are not i a position to pay expenses.) The deadline for the devromm submission is this Sunday (12th), so please let me know by lunchtime tomorrow. Would be great to meet you there!

# %% [markdown]
# - SmokeMachine ... nope
# - Tony O'Dell ... ok
# - Patrick Boeker ... maybe
# - Stefan Seifert

# %%
my $theo24 = q:to/END/;

Proposal title: The Perl & Raku Foundation

Notes: It has been quite a few years ago that there was a Perl devroom. Historically, those were always well attended and packed. Since then a lot has happened and TPRF is excited to share that with other developers from across the globe.

TPRF, as the foundation: - has been funding interns for Outreachy, - supported organisers and events, - funded dozens of grants for developing Perl and Raku.

The Perl programming language – over three decades old – is still evolving and making tremendous steps forward to include a types-system and native OO. New releases will come with 'sensible defaults' that help developers write better code.

Raku is continuously getting better and having had interesting new ways code is being compiled to become even faster as it was before.

Language: en

Why does this proposal fit FOSDEM: The presentation given, will address varius topics related to the TPRF and the community. There will also be presentation about recent and upcoming development on the languages Perl & Raku.

Many of the FOSDEM visitors do have a background using Perl, but might have lost what great features have been added since they started.

Lary Wall himself has been a guest speaker at the Jason building a few years ago, to announce Perl-6, which has been renamed to Raku. The people that attended deserve an update.

The tables we have been granted always draw a great number of people, curious about the latest developments

It has been too long ago that 'we' had a devroom :-)

Prefered slot: Full day (Saturday)

Submitters affinity to the topic: I apply on behalf of the TPRF, which gives a very large support team in organising all the activities around the devroom. A few years ago, TPRF has setup #fosdem-organisers slack channel where we will discuss any planning. TPRF also will take care of delivering content on social media.

About myself: - I am a 'community representative' of TPRF - I have organised several Perl events in the past (notably the Perl Conference in Amsterdam 2017 with a very high attendance of more than 300 people, every 3 days) - volunteered at FOSDEM in the devroom - assist previous organisers (like Wendy) - Oh... did a few FOSDEMs selling beer tokens at Delirium. - I know my way around with quite some aspects of FOSDEM - have arranged social gatherings in Brussel for the community people - know dozen of qualified speakers that are well known within the community

Without any doubt, I can assure that TPRF and the people that partake in organising will deliver a good program for the day.

Special Requirements: if possible, a room in 'K'

END

''

# %%
my &fos = llm-function("Please recast this history as a submission for fosdem 2026 devroom ... $theo24");
fos();

# %%
my $steve26 = q:to/END/;

Proposal title: The Perl & Raku Foundation

Notes: A Perl devroom has been a feature of Fosdem for many years. Historically, those were always well attended and packed. There was a successful devroom presence in 2024. Since then a lot has happened and TPRF is excited to share that with other developers from across the globe.

TPRF, as the foundation: - has been funding interns for Outreachy, - supported organisers and events, - funded dozens of grants for developing Perl and Raku.

The Perl programming language – over three decades old – is still evolving and making tremendous steps forward to include a types-system and native OO. New releases will come with 'sensible defaults' that help developers write better code.

Raku is continuously getting better and having had interesting new ways code is being compiled to become even faster as it was before.

Language: en

Why does this proposal fit FOSDEM: The presentation given, will address varius topics related to the TPRF and the community. There will also be presentation about recent and upcoming development on the languages Perl & Raku.

Many of the FOSDEM visitors do have a background using Perl, but might have lost what great features have been added since they started.

Lary Wall himself has been a guest speaker at the Jason building a few years ago, to announce Perl-6, which has been renamed to Raku. The people that attended deserve an update.

The tables we have been granted always draw a great number of people, curious about the latest developments

It has been too long ago that 'we' had a devroom :-)

Prefered slot: Full day (Saturday)

Submitters affinity to the topic: I apply on behalf of the TPRF, which gives a very large support team in organising all the activities around the devroom. A few years ago, TPRF has setup #fosdem-organisers slack channel where we will discuss any planning. TPRF also will take care of delivering content on social media.

About myself: - I am a 'community representative' of TPRF - I have organised several Perl events in the past (notably the Perl Conference in Amsterdam 2017 with a very high attendance of more than 300 people, every 3 days) - volunteered at FOSDEM in the devroom - assist previous organisers (like Wendy) - Oh... did a few FOSDEMs selling beer tokens at Delirium. - I know my way around with quite some aspects of FOSDEM - have arranged social gatherings in Brussel for the community people - know dozen of qualified speakers that are well known within the community

Without any doubt, I can assure that TPRF and the people that partake in organising will deliver a good program for the day.

Special Requirements: if possible, a room in 'K'

END

# %%
my $devroom-preso-ideas = (
    { Name => 'Alice',   Age => 30, Country => 'USA' },
    { Name => 'Bob',     Age => 25, Country => 'UK' },
    { Name => 'Charlie', Age => 35, Country => 'Canada' },
);
# Out:
# ({Age => 30, Country => USA, Name => Alice} {Age => 25, Country => UK, Name => Bob} {Age => 35, Country => Canada, Name => Charlie})

# %% [markdown]
# Richard Hainsworth
# Lead developer on the doc.raku.org documentation site, the Rakudoc v2 project and architect of the Elucid8 language framework.
# Can a markup language for documentation aspire to be more?
# Why RakuDoc, originally developed purely as a documenting language can aspire to be far more. Focussing on the new enhanced enumerated blocks syntax, and why it is better even than the mighty MS Word.
#
# Elizabeth Mattijsen
# Prolific contributor to Rakudo compliler core, serial attender at Fosdem and implementor of Raku SBOM
# How the CRA will want you to make SBOMs
# The Cyber Resilience Act affects all open source development, either directly or indirectly. This presentation will elaborate on the current state of affairs, and the tools that Raku provides to make your life as a developer easier.
#
# Tony O'Dell
# Author of the zef package manager, Raku's leading ecosystem tool.
# Raku Ecosystem: Current State of Affairs
# A talk through of what has improved over the last year in the ecosystem, the challenges in doing so, and how the architecture changes has improved the user
#
# Patrick Böker
# Mainstay of the Rakudo compiler core development.
# Writing a Terminal Emulator in Raku
# A pretty gutsy story of foreign APIs
#
# Steve Roe
# Editor of the Rakudo Weekly newsletter, author of the new raku.org official website and developer of the HARC stack.
# Raku Roadmap 2026
# Progress on v6.e, RakuAST and other core developments, roadmap for 2026 and invitation to new contributors.
#
# HARC Stack for Beginners
# Create a new Raku Cro website in 5 lines of code. Intro to writing HTML using Air::Functional.
#
#
#
#
# Additional presentation topic ideas (subject to Devroom time allocation):-
#
# Packaging Applications for Scripting languages
# How to use the Executable Runner Generator to create executables for all platforms.
#
# Intro to the BuildToolchainRepo
# How to trivially package Raku modules that need some C code compiled.
#
# Statelessly hitchhiking the GitHub Auth
# How to combine Cro + JWT + OAuth2 to use GitHub as an auth and do so statelessly.
#
# The architecture of the RakuCIBot
# Trivial and safe messaging and state management
